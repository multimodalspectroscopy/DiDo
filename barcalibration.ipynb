# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
lengths = [670, 830, 8362, 2035,5561]
times = [4.2, 4.6,40, 8.8,33]
"""lengths = sorted(lengths)
times = sorted(times)"""
# Out:
# 'lengths = sorted(lengths)\ntimes = sorted(times)'

# %%
fig, axs = plt.subplots(figsize=(10,6))
nirs = [36, 86, 25, 1410,  116, 18, 13, 18008]
nirstimes = [0.12560099999973318, 0.7901390999977593, 0.8194352999998955, 1.1992871000002197,1.4164664999989327, 0.9159548999996332, 0.8118923000001814, 4.997203599999921]
axs.plot(nirs,np.array(nirstimes), '+', color='purple', label='NIRS',markersize=10)
axs2 = axs.twinx()
axs2.plot(lengths,times, '+', color='blue', label='DCS',markersize=10)
axs.set_xscale('log')
axs.set_xlabel('dataset length / s')
axs.set_ylabel('DCS processing duration / s', color='blue')
axs2.set_ylabel('NIRS processing duration / s', color='purple')
plt.savefig('C:\\Users\\user\\OneDrive\\Desktop\\results_1\\dido\\performance.png', dpi=500)

# %%
plt.plot(lengths,times, 'x')
x = np.array(lengths)
y = np.array(times)
b, m = np.polyfit(x, y, 1)
print(b)
plt.plot(x, b * x + m, '-')
# Out:
# 0.005007568091459606
